# %%
from jupyxml import JupyXML

# %%
JupyXML("cd_catalog.xml")
# Out:
# Loading from file
#             <style>
#
#
# .card {
#     border: 1px solid black;
#     box-shadow: grey 2px 2px;
#     padding: 8pt;
#     margin: 4pt 4pt 4pt 8pt
# }
#
# .card-header{
#     font-size: 1.3em;
# }
#
# .card-body{
#     padding-left: 8pt;
# }
#
# .leaf_node{
#     border: 1px solid grey;
#     padding: 8pt;
# }
#             </style>
#
# <div class="card">
#     <div class="card-header" id="heading_0">
#         <button class="btn btn-link" data-toggle="collapse" data-target="#collapse_0"
#             aria-expanded="true" aria-controls="collapse_0">
#           <h3>
#               Item: CATALOG
#           </h3>
#         </button>
#     </div>
#
#     <div id="collapse_0" class="collapse False" aria-labelledby="heading_0" >
#       <div class="card-body">
#         Text:
#
# <div class="card">
#     <div class="card-header" id="heading_0_0">
#         <button class="btn btn-link" data-toggle="collapse" data-target="#collapse_0_0"
# ...
